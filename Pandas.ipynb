# %%
import pandas as pd
import numpy as np

# %%
#SERIES

# %%
# CREATING SERIES
ser = pd.Series(np.random.rand(15))
ser
# Out:
# 0     0.723668
# 1     0.355237
# 2     0.465300
# 3     0.372304
# 4     0.643287
# 5     0.367801
# 6     0.822824
# 7     0.248678
# 8     0.469050
# 9     0.289060
# 10    0.336412
# 11    0.936468
# 12    0.108569
# 13    0.989807
# 14    0.139991
# dtype: float64

# %%
# CHECKING THE TYPE OF SERIES
type(ser)
# Out:
# pandas.core.series.Series

# %%
# CHECKING THE DATATYPE
ser.dtype
# Out:
# dtype('float64')

# %%
# FOR KNOWING THE STARTING ELEMENTS
# head() method return is used for specific number of rows or strings from the top
# head() method returns first 5 rows if a number is not specified
ser.head()
# Out:
# 0    0.723668
# 1    0.355237
# 2    0.465300
# 3    0.372304
# 4    0.643287
# dtype: float64

# %%
# FOR KNOWING THE ENDING ELEMENTS
# tail() method returns a specific number of rows from the last
ser.tail()
# Out:
# 10    0.336412
# 11    0.936468
# 12    0.108569
# 13    0.989807
# 14    0.139991
# dtype: float64

# %%
#DATAFRAME

# %%
#CREATING DATAFRAME
                    #  (row_num , column_num)
df = pd.DataFrame(np.random.rand(10,6),index = np.arange(10))
df
# 'arange' is a function provided by (numpy lib), it generates an array of numbers within a specified range
# Out:
#           0         1         2         3         4         5
# 0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.167042  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.415539  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.226824  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.621398  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.526961  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# CHECKING THE DATATYPE
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# KNOWING ABOUT COLUMN
df.columns
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# CONVERTING DATAFRAME/SERIES INTO ARRAY
df.to_numpy()
# 'to_numpy()' method is used to convert Pandas Dataframe or Series into NumPy array.
# Out:
# array([[0.66067547, 0.9363665 , 0.02803963, 0.19458364, 0.09778141,
#         0.07614108],
#        [0.67691044, 0.552506  , 0.49747108, 0.77652327, 0.25707333,
#         0.76842289],
#        [0.734221  , 0.76914983, 0.6530972 , 0.76262238, 0.69113593,
#         0.55729462],
#        [0.65521119, 0.26237687, 0.84414134, 0.05264609, 0.89165578,
#         0.99941533],
#        [0.54372643, 0.51709371, 0.20875133, 0.98417142, 0.07928406,
#         0.87304828],
#        [0.12135253, 0.58086346, 0.97758984, 0.49107118, 0.41819579,
#         0.07476808],
#        [0.16357087, 0.34322144, 0.39835371, 0.58110203, 0.95199061,
#         0.02727392],
#        [0.65927132, 0.06624112, 0.16434086, 0.87149347, 0.31931558,
#         0.36743338],
#        [0.88554405, 0.61822477, 0.83895675, 0.83163921, 0.52644111,
#         0.97876274],
#        [0.88127167, 0.16278073, 0.46734013, 0.08752649, 0.79176699,
#         0.99252041]])

# %%
# CREATING CSV FILE FROM DATAFRAME
df.to_csv('code.csv')
# csv file will create a spreadsheet file to show data

# %%
# STARTING RECORDS
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063

# %%
# ENDING RECORDS
df.tail()
# Out:
#           0         1         2         3         4         5
# 5  0.167042  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.415539  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.226824  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.621398  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.526961  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# FOR READING CSV FILE
newdf = pd.read_csv('code.csv')
newdf
# Out:
#    Unnamed: 0         0         1         2         3         4         5
# 0           0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1           1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2           2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3           3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4           4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063
# 5           5  0.167042  0.200545  0.445535  0.418276  0.256600  0.426242
# 6           6  0.415539  0.061764  0.936595  0.755336  0.358293  0.362478
# 7           7  0.226824  0.765157  0.701065  0.913315  0.820356  0.784261
# 8           8  0.621398  0.188064  0.977496  0.254408  0.862928  0.016092
# 9           9  0.526961  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# FOR REMOVING INDEX
df.to_csv('index_false.csv',index=False)

# %%
newdf2 = pd.read_csv('index_false.csv')
newdf2
# Out:
#           0         1         2         3         4         5
# 0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.167042  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.415539  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.226824  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.621398  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.526961  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# FOR STATISTICAL COMPUTING
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063

# %%
# now describing statistically
df.describe()
# Out:
#                0          1          2          3          4          5
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.545611   0.465351   0.619594   0.473688   0.562571   0.433434
# std     0.242577   0.333544   0.375665   0.289585   0.295250   0.355615
# min     0.167042   0.038143   0.010514   0.083675   0.017982   0.016092
# 25%     0.406932   0.191184   0.339558   0.274172   0.386174   0.137206
# 50%     0.574179   0.451735   0.760216   0.434260   0.607924   0.394360
# 75%     0.713617   0.757012   0.930509   0.718560   0.776283   0.732379
# max     0.893346   0.885009   0.990153   0.913315   0.979824   0.939862

# %%
# LOC (Label-Based Index Method)
# loc is used to know the value of a specific place

# %%
# FOR KNOWING THE VALUE AT A SPECIFIC PLACE
df
# Out:
#           0         1         2         3         4         5
# 0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.167042  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.415539  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.226824  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.621398  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.526961  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
df.loc[0,2]
# Out:
# 0.9122529543241924

# %%
# CHANGING THE COLUMN NAME
df.columns = list('abcdef')
df
# Out:
#           a         b         c         d         e         f
# 0  0.893346  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.818046  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.735791  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.647096  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.404064  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.167042  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.415539  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.226824  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.621398  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.526961  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# lets check loc again to see column name
df.loc[2,'b']
# Out:
# 0.4605510808126152

# %%
# DROP() FUNCTION
# when we have to drop or delete a row or a column we use (axis) to define them
# for deleting a column, axis = 1 is used to define column
# for deleting a row, axis = 0 is used to define row

# %%
# DELETING A COLUMN
# df.drop(column_name,axis = 1)
df = df.drop('a',axis = 1)

# %%
df
# Out:
#           b         c         d         e         f
# 0  0.732575  0.912253  0.113425  0.643288  0.911655
# 1  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# DELETING A ROW
# df.drop(row_name,axis = 0)
df = df.drop(0,axis = 0)

# %%
df
# Out:
#           b         c         d         e         f
# 1  0.442918  0.990153  0.083675  0.644065  0.576731
# 2  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# ILOC [works on the index]
# ILOC is used to select and access data in dataframme or series using integer based indexing

# %%
# [row_num , column_num]
df.iloc[0,1]
# Out:
# 0.9901526908361132

# %%
# CHANGING A CELL OF A COLUMN
df['c'][1] = 'Magic'
df
# Out:
#           b         c         d         e         f
# 1  0.442918     Magic  0.083675  0.644065  0.576731
# 2  0.460551  0.098729  0.608232  0.572560  0.132931
# 3  0.038143  0.819367  0.450245  0.979824  0.150028
# 4  0.885009  0.304233  0.333465  0.469820  0.034063
# 5  0.200545  0.445535  0.418276  0.256600  0.426242
# 6  0.061764  0.936595  0.755336  0.358293  0.362478
# 7  0.765157  0.701065  0.913315  0.820356  0.784261
# 8  0.188064  0.977496  0.254408  0.862928  0.016092
# 9  0.878789  0.010514  0.806505  0.017982  0.939862

# %%
# FOR DELETING
df.drop(['c','d'],axis = 1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-088a2509b739> in <cell line: 2>()
#       1 # FOR DELETING
# ----> 2 df.drop(['c','d'],axis = 1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4589                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4590             else:
# -> 4591                 new_axis = axis.drop(labels, errors=errors)
#    4592             indexer = axis.get_indexer(new_axis)
#    4593
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6697         if mask.any():
#    6698             if errors != "ignore":
# -> 6699                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700             indexer = indexer[~mask]
#    6701         return self.delete(indexer)
#
# KeyError: "['c', 'd'] not found in axis"

# %%
df
# Out:
#           b         e         f
# 1  0.442918  0.644065  0.576731
# 2  0.460551  0.572560  0.132931
# 3  0.038143  0.979824  0.150028
# 4  0.885009  0.469820  0.034063
# 5  0.200545  0.256600  0.426242
# 6  0.061764  0.358293  0.362478
# 7  0.765157  0.820356  0.784261
# 8  0.188064  0.862928  0.016092
# 9  0.878789  0.017982  0.939862

# %%
# TO CHECK THE NULL VALUE IN A COLUMN
df['f'].isnull()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: f, dtype: bool

# %%
# CREATING NEW DATAFRAME
dict={
      "Name":["John","Trudy","Bob"],
      "Marks":[42,45,47],
      "Sports":["Cricket","Volleyball","Hockey"]
}

# %%
school = pd.DataFrame(dict)

# %%
school
# Out:
#     Name  Marks      Sports
# 0   John     42     Cricket
# 1  Trudy     45  Volleyball
# 2    Bob     47      Hockey

# %%
# converting into csv_file
school.to_csv('school.csv')

# %%
# for removing index
school.to_csv('school_index_false.csv',index=False)
