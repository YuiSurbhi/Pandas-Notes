# %%
import pandas as pd
import numpy as np

# %%
#SERIES

# %%
# CREATING SERIES
ser = pd.Series(np.random.rand(15))
ser
# Out:
# 0     0.715252
# 1     0.838659
# 2     0.023631
# 3     0.046004
# 4     0.955183
# 5     0.314775
# 6     0.336931
# 7     0.791899
# 8     0.208849
# 9     0.433509
# 10    0.490065
# 11    0.422542
# 12    0.010133
# 13    0.989964
# 14    0.214683
# dtype: float64

# %%
# CHECKING THE TYPE OF SERIES
type(ser)
# Out:
# pandas.core.series.Series

# %%
# CHECKING THE DATATYPE
ser.dtype
# Out:
# dtype('float64')

# %%
# FOR KNOWING THE STARTING ELEMENTS
# head() method return is used for specific number of rows or strings from the top
# head() method returns first 5 rows if a number is not specified
ser.head()
# Out:
# 0    0.723668
# 1    0.355237
# 2    0.465300
# 3    0.372304
# 4    0.643287
# dtype: float64

# %%
# FOR KNOWING THE ENDING ELEMENTS
# tail() method returns a specific number of rows from the last
ser.tail()
# Out:
# 10    0.336412
# 11    0.936468
# 12    0.108569
# 13    0.989807
# 14    0.139991
# dtype: float64

# %%
#DATAFRAME

# %%
#CREATING DATAFRAME
                    #  (row_num , column_num)
df = pd.DataFrame(np.random.rand(10,6),index = np.arange(10))
df
# 'arange' is a function provided by (numpy lib), it generates an array of numbers within a specified range
# Out:
#           0         1         2         3         4         5
# 0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.720605  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.480476  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.131468  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.662884  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.312351  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# CHECKING THE DATATYPE
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# KNOWING ABOUT COLUMN
df.columns
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
# CONVERTING DATAFRAME/SERIES INTO ARRAY
df.to_numpy()
# 'to_numpy()' method is used to convert Pandas Dataframe or Series into NumPy array.
# Out:
# array([[0.09655056, 0.7517407 , 0.82038991, 0.24707084, 0.1871239 ,
#         0.44489674],
#        [0.10177586, 0.40356924, 0.29795268, 0.20061112, 0.96338034,
#         0.51742973],
#        [0.06059986, 0.83988051, 0.74892854, 0.21775912, 0.31769693,
#         0.95118025],
#        [0.82916804, 0.14607647, 0.92516923, 0.37636506, 0.6610013 ,
#         0.26388114],
#        [0.87119753, 0.16244641, 0.24164949, 0.66191643, 0.40342979,
#         0.29277204],
#        [0.72060458, 0.00720742, 0.27866995, 0.77890614, 0.65651469,
#         0.44669968],
#        [0.48047566, 0.45104301, 0.27572063, 0.40280288, 0.8106599 ,
#         0.51353721],
#        [0.13146818, 0.74337221, 0.61039019, 0.63721667, 0.17400122,
#         0.62580712],
#        [0.6628841 , 0.1656615 , 0.7021397 , 0.68892322, 0.11125945,
#         0.46075668],
#        [0.31235065, 0.94240531, 0.3039924 , 0.56599795, 0.46968654,
#         0.54453054]])

# %%
# CREATING CSV FILE FROM DATAFRAME
df.to_csv('code.csv')
# csv file will create a spreadsheet file to show data

# %%
# STARTING RECORDS
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772

# %%
# ENDING RECORDS
df.tail()
# Out:
#           0         1         2         3         4         5
# 5  0.720605  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.480476  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.131468  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.662884  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.312351  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# FOR READING CSV FILE
newdf = pd.read_csv('code.csv')
newdf
# Out:
#    Unnamed: 0         0         1         2         3         4         5
# 0           0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1           1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2           2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3           3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4           4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772
# 5           5  0.720605  0.007207  0.278670  0.778906  0.656515  0.446700
# 6           6  0.480476  0.451043  0.275721  0.402803  0.810660  0.513537
# 7           7  0.131468  0.743372  0.610390  0.637217  0.174001  0.625807
# 8           8  0.662884  0.165661  0.702140  0.688923  0.111259  0.460757
# 9           9  0.312351  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# FOR REMOVING INDEX
df.to_csv('index_false.csv',index=False)

# %%
newdf2 = pd.read_csv('index_false.csv')
newdf2
# Out:
#           0         1         2         3         4         5
# 0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.720605  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.480476  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.131468  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.662884  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.312351  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# FOR STATISTICAL COMPUTING
df.head()
# Out:
#           0         1         2         3         4         5
# 0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772

# %%
# now describing statistically
df.describe()
# Out:
#                0          1          2          3          4          5
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.426708   0.461340   0.520500   0.477757   0.475475   0.506149
# std     0.325483   0.337380   0.266563   0.214976   0.289521   0.190787
# min     0.060600   0.007207   0.241649   0.200611   0.111259   0.263881
# 25%     0.109199   0.163250   0.283491   0.279394   0.219767   0.445347
# 50%     0.396413   0.427306   0.457191   0.484400   0.436558   0.487147
# 75%     0.706174   0.749649   0.737231   0.655741   0.659880   0.537755
# max     0.871198   0.942405   0.925169   0.778906   0.963380   0.951180

# %%
# LOC (Label-Based Index Method)
# loc is used to know the value of a specific place

# %%
# FOR KNOWING THE VALUE AT A SPECIFIC PLACE
df
# Out:
#           0         1         2         3         4         5
# 0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.720605  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.480476  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.131468  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.662884  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.312351  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
df.loc[0,2]
# Out:
# 0.8203899065922656

# %%
# CHANGING THE COLUMN NAME
df.columns = list('abcdef')
df
# Out:
#           a         b         c         d         e         f
# 0  0.096551  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.101776  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.060600  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.829168  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.871198  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.720605  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.480476  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.131468  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.662884  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.312351  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# lets check loc again to see column name
df.loc[2,'b']
# Out:
# 0.8398805142771695

# %%
# DROP() FUNCTION
# when we have to drop or delete a row or a column we use (axis) to define them
# for deleting a column, axis = 1 is used to define column
# for deleting a row, axis = 0 is used to define row

# %%
# DELETING A COLUMN
# df.drop(column_name,axis = 1)
df = df.drop('a',axis = 1)

# %%
df
# Out:
#           b         c         d         e         f
# 0  0.751741  0.820390  0.247071  0.187124  0.444897
# 1  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# DELETING A ROW
# df.drop(row_name,axis = 0)
df = df.drop(0,axis = 0)

# %%
df
# Out:
#           b         c         d         e         f
# 1  0.403569  0.297953  0.200611  0.963380  0.517430
# 2  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.007207  0.278670  0.778906  0.656515  0.446700
# 6  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.743372  0.610390  0.637217  0.174001  0.625807
# 8  0.165661  0.702140  0.688923  0.111259  0.460757
# 9  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# ILOC [works on the index]
# ILOC is used to select and access data in dataframme or series using integer based indexing

# %%
# [row_num , column_num]
df.iloc[0,1]
# Out:
# 0.2979526792500644

# %%
# CHANGING A CELL OF A COLUMN
df['c'][1] = 'Magic'
df
# Out:
#           b         c         d         e         f
# 1  0.403569     Magic  0.200611  0.963380  0.517430
# 2  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.007207   0.27867  0.778906  0.656515  0.446700
# 6  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.743372   0.61039  0.637217  0.174001  0.625807
# 8  0.165661   0.70214  0.688923  0.111259  0.460757
# 9  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
df
# Out:
#           b         c         d         e         f
# 1  0.403569     Magic  0.200611  0.963380  0.517430
# 2  0.839881  0.748929  0.217759  0.317697  0.951180
# 3  0.146076  0.925169  0.376365  0.661001  0.263881
# 4  0.162446  0.241649  0.661916  0.403430  0.292772
# 5  0.007207   0.27867  0.778906  0.656515  0.446700
# 6  0.451043  0.275721  0.402803  0.810660  0.513537
# 7  0.743372   0.61039  0.637217  0.174001  0.625807
# 8  0.165661   0.70214  0.688923  0.111259  0.460757
# 9  0.942405  0.303992  0.565998  0.469687  0.544531

# %%
# FOR DELETING
df.drop(['c','d'],axis = 1,inplace=True)

# %%
df
# Out:
#           b         e         f
# 1  0.403569  0.963380  0.517430
# 2  0.839881  0.317697  0.951180
# 3  0.146076  0.661001  0.263881
# 4  0.162446  0.403430  0.292772
# 5  0.007207  0.656515  0.446700
# 6  0.451043  0.810660  0.513537
# 7  0.743372  0.174001  0.625807
# 8  0.165661  0.111259  0.460757
# 9  0.942405  0.469687  0.544531

# %%
# TO CHECK THE NULL VALUE IN A COLUMN
df['f'].isnull()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: f, dtype: bool

# %%
# CREATING NEW DATAFRAME
dict={
      "Name":["John","Trudy","Bob"],
      "Marks":[42,45,47],
      "Sports":["Cricket","Volleyball","Hockey"]
}

# %%
school = pd.DataFrame(dict)

# %%
school
# Out:
#     Name  Marks      Sports
# 0   John     42     Cricket
# 1  Trudy     45  Volleyball
# 2    Bob     47      Hockey

# %%
# converting into csv_file
school.to_csv('school.csv')

# %%
# for removing index
school.to_csv('school_index_false.csv',index=False)
